# %%
import pandas as pd
from psycopg2.extras import execute_values
from db_connection import get_connection
import random
from datetime import datetime, timedelta

# %%
reviews_df = pd.read_csv('dataset/Books_rating.csv')

harry_potter_reviews = reviews_df[reviews_df['Title'].str.contains('Harry Potter', case=False, na=False)]

reviews_df = reviews_df[~reviews_df['Title'].str.contains('Harry Potter', case=False, na=False)]

# 抽取 10% 的其他 reviews
reviews_df = reviews_df.sample(frac=0.1, random_state=42)

# 合併兩個 DataFrame
reviews_df = pd.concat([harry_potter_reviews, reviews_df], ignore_index=True)

# 檢查結果
print(f"Harry Potter reviews: {len(harry_potter_reviews)}")
print(f"Other reviews: {len(reviews_df)}")

# 轉換 Unix Timestamp 到日期格式
reviews_df['review/time'] = pd.to_datetime(reviews_df['review/time'], unit='s')

# 隨機化時間（加上隨機的時、分、秒）
def randomize_time(date):
    random_hours = random.randint(0, 23)
    random_minutes = random.randint(0, 59)
    random_seconds = random.randint(0, 59)
    return date + timedelta(hours=random_hours, minutes=random_minutes, seconds=random_seconds)

# 套用隨機時間
reviews_df['review/time'] = reviews_df['review/time'].apply(randomize_time)
reviews_df.head()
# Out:
# Harry Potter reviews: 13309
# Other reviews: 311978
#            Id                                       Title  Price  \
# 0  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 1  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 2  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 3  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 4  3551551685  Harry Potter und die Kammer des Schreckens   33.4
#
#           User_id   profileName review/helpfulness  review/score  \
# 0             NaN           NaN              43/45           5.0
# 1  A1T80CL9Q3HKDK    A. Moeller                5/5           5.0
# 2   AVHQ9KLO0O6XI  Mikey Ramone                0/0           5.0
# 3  A2O0U4DXE19S2Z        Sabela                0/0           5.0
# 4  A2VN7BFUP041E1     smurray13                1/8           2.0
#
#           review/time                                     review/summary  \
# 0 2000-04-03 05:24:48                          J.K.Rowling did it again!
# 1 2007-08-23 03:39:39    A great way to increase German language skills.
# 2 2012-12-28 07:36:48  Great German Version of &#34;Chamber of Secret...
# 3 2010-12-19 21:36:09                        Harry Potter Made Better :)
# 4 2010-07-14 10:18:02                       Never again, supermoviedeals
#
#                                          review/text
# 0  &quot;Harry Potter und die Kammer des Schrecke...
# 1  I needed a book in German that would motivate ...
# 2  Bought as a gift for a Secret Santa thing. I d...
# 3  Of course, you can't argue with the original B...
# 4  lost package, slow delivery, unhelpful custome...

# %%
reviews_df.columns = [
    'id', 'title', 'price', 'user_id_src', 'profile_name', 
    'review_helpfulness', 'review_score', 'review_time', 
    'review_summary', 'review_text'
]
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
reviews_df[['helpful_yes', 'helpful_total']] = reviews_df['review_helpfulness'].str.split('/', expand=True).fillna(0)
reviews_df['helpful_yes'] = reviews_df['helpful_yes'].astype(int)
reviews_df['helpful_total'] = reviews_df['helpful_total'].astype(int)
reviews_df['price'] = pd.to_numeric(reviews_df['price'], errors='coerce').fillna(0)
reviews_df.head()
# Out:
#            id                                       title  price  \
# 0  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 1  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 2  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 3  3551551685  Harry Potter und die Kammer des Schreckens   33.4
# 4  3551551685  Harry Potter und die Kammer des Schreckens   33.4
#
#       user_id_src  profile_name review_helpfulness  review_score  \
# 0             NaN           NaN              43/45           5.0
# 1  A1T80CL9Q3HKDK    A. Moeller                5/5           5.0
# 2   AVHQ9KLO0O6XI  Mikey Ramone                0/0           5.0
# 3  A2O0U4DXE19S2Z        Sabela                0/0           5.0
# 4  A2VN7BFUP041E1     smurray13                1/8           2.0
#
#           review_time                                     review_summary  \
# 0 2000-04-03 05:24:48                          J.K.Rowling did it again!
# 1 2007-08-23 03:39:39    A great way to increase German language skills.
# 2 2012-12-28 07:36:48  Great German Version of &#34;Chamber of Secret...
# 3 2010-12-19 21:36:09                        Harry Potter Made Better :)
# 4 2010-07-14 10:18:02                       Never again, supermoviedeals
#
#                                          review_text  helpful_yes  \
# 0  &quot;Harry Potter und die Kammer des Schrecke...           43
# 1  I needed a book in German that would motivate ...            5
# 2  Bought as a gift for a Secret Santa thing. I d...            0
# 3  Of course, you can't argue with the original B...            0
# 4  lost package, slow delivery, unhelpful custome...            1
#
#    helpful_total
# 0             45
# 1              5
# 2              0
# 3              0
# 4              8

# %%
with get_connection() as conn:
    with conn.cursor() as cur:
        cur.execute("SELECT title, book_id FROM books;")
        book_map = {title: book_id for title, book_id in cur.fetchall()}

# %%
review_values = []
for _, row in reviews_df.iterrows():
    book_id = book_map.get(row['title'])
    if not book_id:
        print(f"找不到對應的書籍: {row['title']}，跳過...")
        continue

    review_values.append((
        book_id,                             # 書籍ID
        None,                                # 使用者ID，因為是外部來源
        True,                                # 外部評論
        "external",                          # 來源平台 (external)
        row['user_id_src'],                  # 外部平台使用者 ID
        row['profile_name'],                 # 使用者名稱
        row['review_score'],                 # 評分
        row['price'],                        # 價格
        row['helpful_yes'],                  # 有幫助的票數
        row['helpful_total'],                # 總票數
        row['review_time'],                  # 評論時間
        row['review_summary'],               # 評論摘要
        row['review_text']                   # 評論內容
    ))
# Out:
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...
# 找不到對應的書籍: nan，跳過...

# %%
insert_reviews = """
    INSERT INTO reviews (
        book_id, user_id, is_external, source, 
        user_id_src, profile_name, rating, price, 
        helpful_yes, helpful_total, review_time, summary, content
    ) VALUES %s;
"""

# %%
batch_size = 1000  # 每次 1000 筆
total_records = len(review_values)

for i in range(0, total_records, batch_size):
    batch = review_values[i:i + batch_size]
    with get_connection() as conn:
        with conn.cursor() as cur:
            execute_values(cur, insert_reviews, batch)
            conn.commit()
    print(f"Inserted batch {i} - {i + batch_size}")
# Out:
# Inserted batch 0 - 1000
# Inserted batch 1000 - 2000
# Inserted batch 2000 - 3000
# Inserted batch 3000 - 4000
# Inserted batch 4000 - 5000
# Inserted batch 5000 - 6000
# Inserted batch 6000 - 7000
# Inserted batch 7000 - 8000
# Inserted batch 8000 - 9000
# Inserted batch 9000 - 10000
# Inserted batch 10000 - 11000
# Inserted batch 11000 - 12000
# Inserted batch 12000 - 13000
# Inserted batch 13000 - 14000
# Inserted batch 14000 - 15000
# Inserted batch 15000 - 16000
# Inserted batch 16000 - 17000
# Inserted batch 17000 - 18000
# Inserted batch 18000 - 19000
# Inserted batch 19000 - 20000
# Inserted batch 20000 - 21000
# Inserted batch 21000 - 22000
# Inserted batch 22000 - 23000
# Inserted batch 23000 - 24000
# Inserted batch 24000 - 25000
# Inserted batch 25000 - 26000
# Inserted batch 26000 - 27000
# Inserted batch 27000 - 28000
# Inserted batch 28000 - 29000
# Inserted batch 29000 - 30000
# Inserted batch 30000 - 31000
# Inserted batch 31000 - 32000
# Inserted batch 32000 - 33000
# Inserted batch 33000 - 34000
# Inserted batch 34000 - 35000
# Inserted batch 35000 - 36000
# Inserted batch 36000 - 37000
# Inserted batch 37000 - 38000
# Inserted batch 38000 - 39000
# Inserted batch 39000 - 40000
# Inserted batch 40000 - 41000
# Inserted batch 41000 - 42000
# Inserted batch 42000 - 43000
# Inserted batch 43000 - 44000
# Inserted batch 44000 - 45000
# Inserted batch 45000 - 46000
# Inserted batch 46000 - 47000
# Inserted batch 47000 - 48000
# Inserted batch 48000 - 49000
# Inserted batch 49000 - 50000
# Inserted batch 50000 - 51000
# Inserted batch 51000 - 52000
# Inserted batch 52000 - 53000
# Inserted batch 53000 - 54000
# Inserted batch 54000 - 55000
# Inserted batch 55000 - 56000
# Inserted batch 56000 - 57000
# Inserted batch 57000 - 58000
# Inserted batch 58000 - 59000
# Inserted batch 59000 - 60000
# Inserted batch 60000 - 61000
# Inserted batch 61000 - 62000
# Inserted batch 62000 - 63000
# Inserted batch 63000 - 64000
# Inserted batch 64000 - 65000
# Inserted batch 65000 - 66000
# Inserted batch 66000 - 67000
# Inserted batch 67000 - 68000
# Inserted batch 68000 - 69000
# Inserted batch 69000 - 70000
# Inserted batch 70000 - 71000
# Inserted batch 71000 - 72000
# Inserted batch 72000 - 73000
# Inserted batch 73000 - 74000
# Inserted batch 74000 - 75000
# Inserted batch 75000 - 76000
# Inserted batch 76000 - 77000
# Inserted batch 77000 - 78000
# Inserted batch 78000 - 79000
# Inserted batch 79000 - 80000
# Inserted batch 80000 - 81000
# Inserted batch 81000 - 82000
# Inserted batch 82000 - 83000
# Inserted batch 83000 - 84000
# Inserted batch 84000 - 85000
# Inserted batch 85000 - 86000
# Inserted batch 86000 - 87000
# Inserted batch 87000 - 88000
# Inserted batch 88000 - 89000
# Inserted batch 89000 - 90000
# Inserted batch 90000 - 91000
# Inserted batch 91000 - 92000
# Inserted batch 92000 - 93000
# Inserted batch 93000 - 94000
# Inserted batch 94000 - 95000
# Inserted batch 95000 - 96000
# Inserted batch 96000 - 97000
# Inserted batch 97000 - 98000
# Inserted batch 98000 - 99000
# Inserted batch 99000 - 100000
# Inserted batch 100000 - 101000
# Inserted batch 101000 - 102000
# Inserted batch 102000 - 103000
# Inserted batch 103000 - 104000
# Inserted batch 104000 - 105000
# Inserted batch 105000 - 106000
# Inserted batch 106000 - 107000
# Inserted batch 107000 - 108000
# Inserted batch 108000 - 109000
# Inserted batch 109000 - 110000
# Inserted batch 110000 - 111000
# Inserted batch 111000 - 112000
# Inserted batch 112000 - 113000
# Inserted batch 113000 - 114000
# Inserted batch 114000 - 115000
# Inserted batch 115000 - 116000
# Inserted batch 116000 - 117000
# Inserted batch 117000 - 118000
# Inserted batch 118000 - 119000
# Inserted batch 119000 - 120000
# Inserted batch 120000 - 121000
# Inserted batch 121000 - 122000
# Inserted batch 122000 - 123000
# Inserted batch 123000 - 124000
# Inserted batch 124000 - 125000
# Inserted batch 125000 - 126000
# Inserted batch 126000 - 127000
# Inserted batch 127000 - 128000
# Inserted batch 128000 - 129000
# Inserted batch 129000 - 130000
# Inserted batch 130000 - 131000
# Inserted batch 131000 - 132000
# Inserted batch 132000 - 133000
# Inserted batch 133000 - 134000
# Inserted batch 134000 - 135000
# Inserted batch 135000 - 136000
# Inserted batch 136000 - 137000
# Inserted batch 137000 - 138000
# Inserted batch 138000 - 139000
# Inserted batch 139000 - 140000
# Inserted batch 140000 - 141000
# Inserted batch 141000 - 142000
# Inserted batch 142000 - 143000
# Inserted batch 143000 - 144000
# Inserted batch 144000 - 145000
# Inserted batch 145000 - 146000
# Inserted batch 146000 - 147000
# Inserted batch 147000 - 148000
# Inserted batch 148000 - 149000
# Inserted batch 149000 - 150000
# Inserted batch 150000 - 151000
# Inserted batch 151000 - 152000
# Inserted batch 152000 - 153000
# Inserted batch 153000 - 154000
# Inserted batch 154000 - 155000
# Inserted batch 155000 - 156000
# Inserted batch 156000 - 157000
# Inserted batch 157000 - 158000
# Inserted batch 158000 - 159000
# Inserted batch 159000 - 160000
# Inserted batch 160000 - 161000
# Inserted batch 161000 - 162000
# Inserted batch 162000 - 163000
# Inserted batch 163000 - 164000
# Inserted batch 164000 - 165000
# Inserted batch 165000 - 166000
# Inserted batch 166000 - 167000
# Inserted batch 167000 - 168000
# Inserted batch 168000 - 169000
# Inserted batch 169000 - 170000
# Inserted batch 170000 - 171000
# Inserted batch 171000 - 172000
# Inserted batch 172000 - 173000
# Inserted batch 173000 - 174000
# Inserted batch 174000 - 175000
# Inserted batch 175000 - 176000
# Inserted batch 176000 - 177000
# Inserted batch 177000 - 178000
# Inserted batch 178000 - 179000
# Inserted batch 179000 - 180000
# Inserted batch 180000 - 181000
# Inserted batch 181000 - 182000
# Inserted batch 182000 - 183000
# Inserted batch 183000 - 184000
# Inserted batch 184000 - 185000
# Inserted batch 185000 - 186000
# Inserted batch 186000 - 187000
# Inserted batch 187000 - 188000
# Inserted batch 188000 - 189000
# Inserted batch 189000 - 190000
# Inserted batch 190000 - 191000
# Inserted batch 191000 - 192000
# Inserted batch 192000 - 193000
# Inserted batch 193000 - 194000
# Inserted batch 194000 - 195000
# Inserted batch 195000 - 196000
# Inserted batch 196000 - 197000
# Inserted batch 197000 - 198000
# Inserted batch 198000 - 199000
# Inserted batch 199000 - 200000
# Inserted batch 200000 - 201000
# Inserted batch 201000 - 202000
# Inserted batch 202000 - 203000
# Inserted batch 203000 - 204000
# Inserted batch 204000 - 205000
# Inserted batch 205000 - 206000
# Inserted batch 206000 - 207000
# Inserted batch 207000 - 208000
# Inserted batch 208000 - 209000
# Inserted batch 209000 - 210000
# Inserted batch 210000 - 211000
# Inserted batch 211000 - 212000
# Inserted batch 212000 - 213000
# Inserted batch 213000 - 214000
# Inserted batch 214000 - 215000
# Inserted batch 215000 - 216000
# Inserted batch 216000 - 217000
# Inserted batch 217000 - 218000
# Inserted batch 218000 - 219000
# Inserted batch 219000 - 220000
# Inserted batch 220000 - 221000
# Inserted batch 221000 - 222000
# Inserted batch 222000 - 223000
# Inserted batch 223000 - 224000
# Inserted batch 224000 - 225000
# Inserted batch 225000 - 226000
# Inserted batch 226000 - 227000
# Inserted batch 227000 - 228000
# Inserted batch 228000 - 229000
# Inserted batch 229000 - 230000
# Inserted batch 230000 - 231000
# Inserted batch 231000 - 232000
# Inserted batch 232000 - 233000
# Inserted batch 233000 - 234000
# Inserted batch 234000 - 235000
# Inserted batch 235000 - 236000
# Inserted batch 236000 - 237000
# Inserted batch 237000 - 238000
# Inserted batch 238000 - 239000
# Inserted batch 239000 - 240000
# Inserted batch 240000 - 241000
# Inserted batch 241000 - 242000
# Inserted batch 242000 - 243000
# Inserted batch 243000 - 244000
# Inserted batch 244000 - 245000
# Inserted batch 245000 - 246000
# Inserted batch 246000 - 247000
# Inserted batch 247000 - 248000
# Inserted batch 248000 - 249000
# Inserted batch 249000 - 250000
# Inserted batch 250000 - 251000
# Inserted batch 251000 - 252000
# Inserted batch 252000 - 253000
# Inserted batch 253000 - 254000
# Inserted batch 254000 - 255000
# Inserted batch 255000 - 256000
# Inserted batch 256000 - 257000
# Inserted batch 257000 - 258000
# Inserted batch 258000 - 259000
# Inserted batch 259000 - 260000
# Inserted batch 260000 - 261000
# Inserted batch 261000 - 262000
# Inserted batch 262000 - 263000
# Inserted batch 263000 - 264000
# Inserted batch 264000 - 265000
# Inserted batch 265000 - 266000
# Inserted batch 266000 - 267000
# Inserted batch 267000 - 268000
# Inserted batch 268000 - 269000
# Inserted batch 269000 - 270000
# Inserted batch 270000 - 271000
# Inserted batch 271000 - 272000
# Inserted batch 272000 - 273000
# Inserted batch 273000 - 274000
# Inserted batch 274000 - 275000
# Inserted batch 275000 - 276000
# Inserted batch 276000 - 277000
# Inserted batch 277000 - 278000
# Inserted batch 278000 - 279000
# Inserted batch 279000 - 280000
# Inserted batch 280000 - 281000
# Inserted batch 281000 - 282000
# Inserted batch 282000 - 283000
# Inserted batch 283000 - 284000
# Inserted batch 284000 - 285000
# Inserted batch 285000 - 286000
# Inserted batch 286000 - 287000
# Inserted batch 287000 - 288000
# Inserted batch 288000 - 289000
# Inserted batch 289000 - 290000
# Inserted batch 290000 - 291000
# Inserted batch 291000 - 292000
# Inserted batch 292000 - 293000
# Inserted batch 293000 - 294000
# Inserted batch 294000 - 295000
# Inserted batch 295000 - 296000
# Inserted batch 296000 - 297000
# Inserted batch 297000 - 298000
# Inserted batch 298000 - 299000
# Inserted batch 299000 - 300000
# Inserted batch 300000 - 301000
# Inserted batch 301000 - 302000
# Inserted batch 302000 - 303000
# Inserted batch 303000 - 304000
# Inserted batch 304000 - 305000
# Inserted batch 305000 - 306000
# Inserted batch 306000 - 307000
# Inserted batch 307000 - 308000
# Inserted batch 308000 - 309000
# Inserted batch 309000 - 310000
# Inserted batch 310000 - 311000
# Inserted batch 311000 - 312000
